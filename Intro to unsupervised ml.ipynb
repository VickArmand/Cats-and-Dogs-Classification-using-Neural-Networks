# %%
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import sys
# !pip install opencv-python

import cv2

print('All libraries present')
# Out:
# All libraries present

# %%
kmeans= KMeans(n_clusters=3,random_state=0)

# %%
path= 'C:/Users/VICKFURY/Documents/Python Scripts/ml/datasets/dogs.jpeg'
img=cv2.imread(path)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
(h,w,c)=img.shape

# %%
img=img.reshape((h*w,c))
print('width : ',w)
print('height : ',h)
print('channel: ',c)
print('shape: ',img.shape)
# Out:
# width :  272
# height :  185
# channel:  3
# shape:  (50320, 3)

# %% [markdown]
# # Looking at the dominant colors in an image

# %%
kmeans.fit(img)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
labels=kmeans.predict(img)
labels.shape
# Out:
# (50320,)

# %%
np.set_printoptions(threshold=sys.maxsize)

# %%
labels= labels.reshape((h,w))
print(labels.shape)
# Out:
# (185, 272)

# %%
plt.imshow(labels)

# %%
centers=[centers.astype(int) for centers in kmeans.cluster_centers_]
centers
# Out:
# [array([210, 174, 143]), array([251, 247, 243]), array([29, 21, 20])]

# %%
blob=np.ones((100,100,3))

# %%
blob1=blob*centers[0]
blob1=(blob1*255).astype(np.uint8)
plt.imshow(cv2.cvtColor(blob1,cv2.COLOR_BGR2RGB))

# %%
blob2=blob*centers[1]
blob2=(blob2*255).astype(np.uint8)
plt.imshow(cv2.cvtColor(blob2,cv2.COLOR_BGR2RGB))

# %%
blob3=blob*centers[2]
blob3=(blob3*255).astype(np.uint8)
plt.imshow(cv2.cvtColor(blob3,cv2.COLOR_BGR2RGB))

# %%
print(centers)
# Out:
# [array([210, 174, 143]), array([251, 247, 243]), array([29, 21, 20])]
